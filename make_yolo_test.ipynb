# %%
from ultralytics import YOLO
import os

# ==========================================
# 1. 설정
# ==========================================
# 다운로드 받은 OBB 데이터셋 폴더 이름으로 변경해주세요
# (Roboflow 등에서 다운받으면 폴더명이 다를 수 있으니 꼭 확인하세요)
dataset_folder_name = "license_plate_dataset" 

# data.yaml 파일의 절대 경로를 자동으로 찾습니다
current_dir = os.getcwd()
data_yaml_path = os.path.join(current_dir, dataset_folder_name, "data.yaml")

print(f"데이터셋 경로: {data_yaml_path}")

# ==========================================
# 2. 모델 생성 및 학습 (OBB 모드)
# ==========================================
# 중요: OBB 학습을 위해 'yolov8n-obb.pt' 모델을 로드합니다.
# 처음 실행 시 자동으로 다운로드 됩니다.
model = YOLO("yolov8n-obb.pt") 

print(">>> OBB(회전 박스) 학습을 시작합니다... (시간이 좀 걸립니다)")

# 학습 시작!
# 데이터셋이 OBB 형식이라면 모델이 자동으로 감지하여 Oriented Bounding Box 학습을 수행합니다.
model.train(
    data=data_yaml_path, 
    epochs=50, 
    imgsz=800,       # 416보다 훨씬 정밀하게 각도를 계산합니다.
    batch=8,         # 해상도가 높아지면 메모리를 많이 먹으므로 배치를 조금 줄였습니다.
    device='cpu'
)

print(">>> 학습 완료!")
# Out:
# 데이터셋 경로: c:\jupyter ex\license_plate_dataset\data.yaml
# >>> OBB(회전 박스) 학습을 시작합니다... (시간이 좀 걸립니다)
# New https://pypi.org/project/ultralytics/8.3.240 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.11.9 torch-2.9.1+cpu CPU (Intel Core i5-10400F 2.90GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\jupyter ex\license_plate_dataset\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=800, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\jupyter ex\runs\obb\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    823174  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLOv8n-obb summary: 144 layers, 3,082,710 parameters, 3,082,694 gradients, 8.4 GFLOPs
#
# Transferred 391/397 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 236.160.4 MB/s, size: 41.6 KB)
# train: Scanning C:\jupyter ex\license_plate_dataset\train\labels.cache... 102 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 102/102 102.0Kit/s 0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 232.845.4 MB/s, size: 36.1 KB)
# val: Scanning C:\jupyter ex\license_plate_dataset\valid\labels.cache... 9 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9/9 9.0Kit/s 0.0s
# Plotting labels to C:\jupyter ex\runs\obb\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 63 weight(decay=0.0), 73 weight(decay=0.0005), 72 bias(decay=0.0)
# Image sizes 800 train, 800 val
# Using 0 dataloader workers
# Logging results to C:\jupyter ex\runs\obb\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.652      4.111      1.568         15        800: 100% ━━━━━━━━━━━━ 13/13 3.4s/it 44.0s3.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s3.1s
#                    all          9         17      0.208      0.235      0.188     0.0661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.194      2.514      1.355         35        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.4s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.664      0.647      0.716      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.019      1.574      1.329         15        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.9s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s3.0s
#                    all          9         17      0.929      0.824      0.829      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.003      1.181      1.207         21        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.9s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17          1      0.817      0.872      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G     0.9228       1.02      1.237         20        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.885      0.941      0.854      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G     0.8924     0.8908      1.276         19        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.6s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.878      0.941      0.868      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      0.898      0.857      1.239         22        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.9s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.888      0.941      0.876      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G     0.8503     0.7861      1.215         19        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.6s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.912      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G     0.8272     0.7372      1.206         16        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.962      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G     0.8212     0.6943      1.179         15        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.7s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.988      0.941      0.978      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.8145     0.6455      1.236         24        800: 100% ━━━━━━━━━━━━ 13/13 3.2s/it 41.6s3.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.901      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.8312     0.6496      1.195         12        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.7s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.883      0.941      0.892      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G     0.7555     0.5999      1.132         15        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.882      0.941      0.899      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.7673     0.6076      1.217         19        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.8s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.885      0.941      0.942      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.7668     0.5743      1.177         18        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.8s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.947      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.7444     0.5749      1.187         10        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.7s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.968      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G     0.6813      0.505      1.137         16        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.8s
#                    all          9         17      0.923      0.941      0.951       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G     0.8157     0.5718      1.255         25        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.0s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.936      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G     0.7386     0.5388      1.153         18        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s3.0s
#                    all          9         17      0.886      0.941       0.91      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G     0.7626     0.5316       1.17          9        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.867      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G     0.7693     0.5089      1.179         27        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.5s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.879      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.7376     0.5381       1.19         18        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.877      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.6941     0.4869      1.153         19        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.7s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s3.0s
#                    all          9         17      0.885      0.941        0.9      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.7335     0.4884      1.161         24        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s3.1s
#                    all          9         17      0.885      0.941      0.903      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.6894     0.4568      1.181         13        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s3.0s
#                    all          9         17      0.885      0.941      0.907      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.6897     0.4613       1.12         10        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.4s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.907      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.7583     0.4912      1.234         21        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.0s3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s4.0s
#                    all          9         17      0.889      0.941      0.895      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.6745     0.4677       1.16         20        800: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.6s2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.881      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.6914     0.4574      1.174         14        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.0s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.889      0.941      0.882      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G     0.6487     0.4519      1.135         11        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.8s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s2.8s
#                    all          9         17      0.886      0.941      0.873      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.6902     0.4717      1.122         12        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.4s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.885      0.941      0.866      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.6474     0.4382      1.138         15        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.2s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.884      0.941      0.865      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.6485     0.4457      1.117         23        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.5s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.899      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G      0.696     0.4388      1.183         19        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.7s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.906      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G     0.6465     0.4427      1.178         23        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.8s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.907      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.6774     0.4353      1.218         23        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.3s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.906      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.6244     0.4183      1.171         14        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.3s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.905      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.6235     0.4106      1.117         15        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.6s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.899      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.6615     0.4261      1.137         17        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.2s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.9s
#                    all          9         17      0.886      0.941      0.906      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.6363     0.4363      1.113         30        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.5s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.906      0.701
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      0.601     0.4002      1.098         12        800: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.5s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.906      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.6026     0.4028      1.154         11        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.0s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.912      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.6192     0.4101      1.117         11        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 37.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.905      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.6113     0.4026      1.136         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 37.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s2.7s
#                    all          9         17      0.886      0.941      0.911      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.5632     0.3794      1.107         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 37.8s2.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.911      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.5818     0.3813      1.151         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.0s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s2.8s
#                    all          9         17      0.886      0.941      0.911      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.5823     0.3852      1.134         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.1s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.912       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.5841     0.3831      1.168         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 38.1s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.913      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.5567     0.3781      1.134         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 37.9s2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.913      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.5405     0.3641      1.102         12        800: 100% ━━━━━━━━━━━━ 13/13 2.9s/it 37.9s2.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.8s
#                    all          9         17      0.886      0.941      0.913      0.704
#
# 50 epochs completed in 0.558 hours.
# Optimizer stripped from C:\jupyter ex\runs\obb\train\weights\last.pt, 6.5MB
# Optimizer stripped from C:\jupyter ex\runs\obb\train\weights\best.pt, 6.5MB
#
# Validating C:\jupyter ex\runs\obb\train\weights\best.pt...
# Ultralytics 8.3.235  Python-3.11.9 torch-2.9.1+cpu CPU (Intel Core i5-10400F 2.90GHz)
# YOLOv8n-obb summary (fused): 81 layers, 3,077,414 parameters, 0 gradients, 8.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s2.5s
#                    all          9         17      0.987      0.941      0.979      0.785
# Speed: 1.7ms preprocess, 85.4ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to C:\jupyter ex\runs\obb\train
# >>> 학습 완료!
